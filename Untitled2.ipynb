# %%
import pandas as pd

# %%
details = pd.read_csv('./responses.csv')

# %%
print(type(details))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
details.describe()
# Out:
#        Please rate the quality of the image  \
# count                             63.000000
# mean                               3.698413
# std                                1.087093
# min                                1.000000
# 25%                                3.000000
# 50%                                4.000000
# 75%                                4.500000
# max                                5.000000
#
#        Please rate the quality of the image.1  \
# count                               62.000000
# mean                                 4.000000
# std                                  1.101415
# min                                  1.000000
# 25%                                  4.000000
# 50%                                  4.000000
# 75%                                  5.000000
# max                                  5.000000
#
#        Please rate the quality of the image.2  \
# count                               63.000000
# ...

# %%
b = details['Please insert your Microworkers ID'] 
print(b)
for i in b:
    print
# Out:
# 0        gs_matthias
# 1           b6b1c2fd
# 2           86c8f83a
# 3           d7fecef0
# 4           6d6c5b99
#            ...
# 58             right
# 59          a24bff91
# 60     [a5a09c76] pt
# 61      saiful islam
# 62     Humayun Ahmed
# Name: Please insert your Microworkers ID, Length: 63, dtype: object

# %%
counter = 0
for i in b:
#     print(len(i))
#     print(i)
    if len(i) == 8:
        
        counter +=1
        
#         print(i)
        details['Please insert your Microworkers ID'] = i
print(details)    
# print('Number of valid ID : ',counter)
# details['Please insert your Microworkers ID'] = i
# Out:
#               Timestamp Please insert your Microworkers ID  Gender  \
# 0   19/12/2016 17:36:09                           a24bff91    Male
# 1   19/12/2016 17:51:59                           a24bff91    Male
# 2   19/12/2016 17:52:15                           a24bff91    Male
# 3   19/12/2016 17:53:01                           a24bff91    Male
# 4   19/12/2016 17:53:03                           a24bff91    Male
# ..                  ...                                ...     ...
# 58  19/12/2016 18:27:51                           a24bff91    Male
# 59  19/12/2016 18:29:51                           a24bff91    Male
# 60  19/12/2016 18:33:11                           a24bff91  Female
# 61  19/12/2016 18:33:50                           a24bff91    Male
# 62  19/12/2016 18:34:28                           a24bff91    Male
#
#                Age  \
# 0      26-35 years
# 1      36-45 years
# 2      18-25 years
# 3      26-35 years
# 4      26-35 years
# ..             ...
# ...
